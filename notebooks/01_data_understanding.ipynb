# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 20)

# %%
employees = pd.read_csv("../data/employees_raw.csv")
regions = pd.read_csv("../data/region_benefit_profiles.csv")

# %%
employees.head()
# Out:
#    qemployee_id  age  gender marital_status    salary employment_type  \
# 0         12324   28    Male       Divorced  44047.60       Full-time
# 1         17825   23    Male        Married  80111.28       Full-time
# 2         15200   39    Male        Married  69855.65       Full-time
# 3         16690   31  Female        Married  91567.33       Full-time
# 4         17465   42  Female         Single  59861.68        Contract
#
#     region has_dependents  tenure_years  enrolled application_date  \
# 0     West             No           1.4         0       2024-04-14
# 1  Midwest            Yes           0.5         1       2024-05-09
# 2    South            Yes           3.4         1       22/06/2024
# 3    South             No           1.2         1       2024-08-16
# 4  Midwest            Yes          23.8         0       13/05/2024
#
#   last_contact_date last_contact_channel plan_tier_requested  \
# 0        2024-03-30                  SMS               basic
# ...

# %%
regions.head()
# Out:
#       region  n_employees_region  hist_enrollment_rate_region  \
# 0    Midwest                2488                        0.617
# 1  Northeast                2506                        0.612
# 2      South                2424                        0.628
# 3       West                2582                        0.613
#
#    avg_salary_region  avg_premium_cost_usd  benefits_broker_rating  \
# 0           64921.46                   595                     4.4
# 1           65008.32                   455                     3.1
# 2           65200.49                   481                     3.3
# 3           65007.07                   574                     4.7
#
#    hr_outreach_capacity  open_enrollment_window_days state_mandate_level
# 0                   469                           18                High
# 1                   151                           38                 low
# 2                   324                           17                 MED
# ...

# %%
employees.shape
# Out:
# (10008, 18)

# %%
regions.shape
# Out:
# (4, 9)

# %%
employees.columns
# Out:
# Index(['qemployee_id', 'age', 'gender', 'marital_status', 'salary',
#        'employment_type', 'region', 'has_dependents', 'tenure_years',
#        'enrolled', 'application_date', 'last_contact_date',
#        'last_contact_channel', 'plan_tier_requested', 'broker_channel',
#        'prior_year_enrolled', 'legacy_propensity_score', 'outreach_notes'],
#       dtype='object')

# %%
regions.columns
# Out:
# Index(['region', 'n_employees_region', 'hist_enrollment_rate_region',
#        'avg_salary_region', 'avg_premium_cost_usd', 'benefits_broker_rating',
#        'hr_outreach_capacity', 'open_enrollment_window_days',
#        'state_mandate_level'],
#       dtype='object')

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   qemployee_id             10008 non-null  int64
#  1   age                      10008 non-null  int64
#  2   gender                   10008 non-null  object
#  3   marital_status           10008 non-null  object
#  4   salary                   10008 non-null  float64
#  5   employment_type          10008 non-null  object
#  6   region                   10008 non-null  object
#  7   has_dependents           10008 non-null  object
#  8   tenure_years             10008 non-null  float64
#  9   enrolled                 10008 non-null  int64
#  10  application_date         9289 non-null   object
#  11  last_contact_date        10008 non-null  object
#  12  last_contact_channel     8823 non-null   object
#  13  plan_tier_requested      9482 non-null   object
# ...

# %%
regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   region                       4 non-null      object
#  1   n_employees_region           4 non-null      int64
#  2   hist_enrollment_rate_region  4 non-null      float64
#  3   avg_salary_region            4 non-null      float64
#  4   avg_premium_cost_usd         4 non-null      int64
#  5   benefits_broker_rating       4 non-null      float64
#  6   hr_outreach_capacity         4 non-null      int64
#  7   open_enrollment_window_days  4 non-null      int64
#  8   state_mandate_level          4 non-null      object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 420.0+ bytes

# %%
employees.isnull().sum()
# Out:
# qemployee_id                  0
# age                           0
# gender                        0
# marital_status                0
# salary                        0
# employment_type               0
# region                        0
# has_dependents                0
# tenure_years                  0
# enrolled                      0
# application_date            719
# last_contact_date             0
# last_contact_channel       1185
# plan_tier_requested         526
# broker_channel              470
# prior_year_enrolled           0
# legacy_propensity_score     908
# outreach_notes             1453
# dtype: int64

# %%
regions.isnull().sum()
# Out:
# region                         0
# n_employees_region             0
# hist_enrollment_rate_region    0
# avg_salary_region              0
# avg_premium_cost_usd           0
# benefits_broker_rating         0
# hr_outreach_capacity           0
# open_enrollment_window_days    0
# state_mandate_level            0
# dtype: int64

# %%
employees.duplicated().sum()
# Out:
# np.int64(0)

# %%
regions.duplicated().sum()
# Out:
# np.int64(0)

# %%
employees["qemployee_id"].duplicated().sum()
# Out:
# np.int64(8)

# %%
employees[employees["qemployee_id"].duplicated(keep=False)]
# Out:
#       qemployee_id  age  gender marital_status    salary employment_type  \
# 91           17959   32  Female        Married  54893.19        Contract
# 288          14868   36    Male        Married  71383.69       Full-time
# 455          10484   55    Male         Single  65664.82       Full-time
# 1327         13441   36    Male        Married  72902.08       Part-time
# 1589         14846   64    Male        Married  50514.16       Full-time
# 2061         14868   36    Male        Married  71383.69       Full-time
# 2241         17959   32  Female        Married  54893.19        Contract
# 4188         10484   55    Male         Single  65664.82       Full-time
# 6139         13840   36  Female        Married  84764.82       Part-time
# 6582         10311   50  Female         Single  57869.86       Full-time
# 7370         14846   64    Male        Married  50514.16       Full-time
# 7414         16819   47    Male        Married  78944.56       Full-time
# ...

# %%
employees.describe()
# Out:
#        qemployee_id           age         salary  tenure_years      enrolled  \
# count  10008.000000  10008.000000   10008.000000  10008.000000  10008.000000
# mean   14999.756994     43.003197   65034.633918      3.966447      0.617106
# std     2886.750141     12.284623   14921.509635      3.894377      0.486117
# min    10001.000000     22.000000    2207.790000      0.000000      0.000000
# 25%    12500.750000     33.000000   54717.165000      1.200000      0.000000
# 50%    14998.500000     43.000000   65063.065000      2.800000      1.000000
# 75%    17499.250000     54.000000   75053.687500      5.600000      1.000000
# max    20000.000000     64.000000  120312.000000     36.000000      1.000000
#
#        prior_year_enrolled  legacy_propensity_score
# count         10008.000000              9100.000000
# mean             -0.047062                 0.605136
# std               0.871637                 0.363105
# min              -1.000000                 0.010000
# ...

# %%
regions.describe()
# Out:
#        n_employees_region  hist_enrollment_rate_region  avg_salary_region  \
# count            4.000000                     4.000000           4.000000
# mean          2500.000000                     0.617500       65034.335000
# std             65.012819                     0.007326         117.994929
# min           2424.000000                     0.612000       64921.460000
# 25%           2472.000000                     0.612750       64985.667500
# 50%           2497.000000                     0.615000       65007.695000
# 75%           2525.000000                     0.619750       65056.362500
# max           2582.000000                     0.628000       65200.490000
#
#        avg_premium_cost_usd  benefits_broker_rating  hr_outreach_capacity  \
# count              4.000000                  4.0000               4.00000
# mean             526.250000                  3.8750             345.25000
# std               68.631261                  0.7932             143.66251
# ...

# %%
employees.describe(include="object")
# Out:
#        gender marital_status employment_type region has_dependents  \
# count   10008          10008           10008  10008          10008
# unique      3              4               3      4              2
# top      Male        Married       Full-time   West            Yes
# freq     4820           4595            7046   2586           5999
#
#        application_date last_contact_date last_contact_channel  \
# count              9289             10008                 8823
# unique             1049               390                   12
# top          2024-04-08        2024-10-19                EMAIL
# freq                 36                43                 1166
#
#        plan_tier_requested broker_channel           outreach_notes
# count                 9482           9538                     8555
# unique                  15              3                        6
# top               STANDARD         Direct  Declined - cost concern
# ...

# %%
regions.describe(include="object")
# Out:
#          region state_mandate_level
# count         4                   4
# unique        4                   4
# top     Midwest                High
# freq          1                   1

# %%
employees["gender"].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
employees["marital_status"].unique()
# Out:
# array(['Divorced', 'Married', 'Single', 'Widowed'], dtype=object)

# %%
employees["employment_type"].unique()
# Out:
# array(['Full-time', 'Contract', 'Part-time'], dtype=object)

# %%
employees["plan_tier_requested"].unique()
# Out:
# array(['basic', 'STANDARD', 'Silver', 'premium plan', 'Standard', 'Basic',
#        'silver plan', 'standard', 'BASIC', nan, 'PREMIUM', 'Gold Plan',
#        'Bronze', 'gold', 'Premium', 'Gold'], dtype=object)

# %%
employees["last_contact_channel"].unique()
# Out:
# array(['SMS', 'Call', 'none', 'email', 'EMAIL', 'e-mail', 'Phone', 'sms',
#        'phone', 'Email', nan, 'Text', 'PHONE'], dtype=object)

# %%
regions["state_mandate_level"].unique()
# Out:
# array(['High', 'low', 'MED', 'Low'], dtype=object)

# %%
employees.describe()
# Out:
#        qemployee_id           age         salary  tenure_years      enrolled  \
# count  10008.000000  10008.000000   10008.000000  10008.000000  10008.000000
# mean   14999.756994     43.003197   65034.633918      3.966447      0.617106
# std     2886.750141     12.284623   14921.509635      3.894377      0.486117
# min    10001.000000     22.000000    2207.790000      0.000000      0.000000
# 25%    12500.750000     33.000000   54717.165000      1.200000      0.000000
# 50%    14998.500000     43.000000   65063.065000      2.800000      1.000000
# 75%    17499.250000     54.000000   75053.687500      5.600000      1.000000
# max    20000.000000     64.000000  120312.000000     36.000000      1.000000
#
#        prior_year_enrolled  legacy_propensity_score
# count         10008.000000              9100.000000
# mean             -0.047062                 0.605136
# std               0.871637                 0.363105
# min              -1.000000                 0.010000
# ...

# %%
employees["salary"].sort_values().head(20)
# Out:
# 8425     2207.79
# 587      5484.33
# 3821    13376.31
# 8579    13932.70
# 5982    16027.53
# 8610    16593.92
# 3792    18260.77
# 2685    18382.70
# 2182    18396.11
# 2567    18866.26
# 1743    18888.35
# 7589    18935.17
# 186     19562.61
# 6429    19569.20
# 6242    20007.11
# 3702    20221.06
# 6120    20674.61
# 757     20685.34
# 6479    20710.56
# 9398    20967.64
# Name: salary, dtype: float64

# %%
employees["tenure_years"].sort_values(ascending=False).head(20)
# Out:
# 4325    36.0
# 3694    34.7
# 2813    34.4
# 2920    33.8
# 7069    33.2
# 8584    31.5
# 3380    27.2
# 2408    27.2
# 6504    26.9
# 6165    26.7
# 3393    26.5
# 5110    26.3
# 1153    26.3
# 5481    26.0
# 8470    25.8
# 5646    25.5
# 6710    25.5
# 150     25.2
# 8660    24.5
# 2567    24.4
# Name: tenure_years, dtype: float64

# %%
employees["salary"].sort_values().tail(20)
# Out:
# 9955    106880.90
# 1846    107159.27
# 3763    107710.61
# 6611    108368.18
# 4564    108532.56
# 2445    108879.21
# 6363    108945.17
# 2072    109161.74
# 2230    109424.90
# 8831    109908.58
# 1505    110098.70
# 2664    111745.22
# 6035    112101.07
# 2810    112735.68
# 5079    112776.42
# 33      113254.75
# 4546    115182.12
# 8094    115733.64
# 1577    117588.07
# 3655    120312.00
# Name: salary, dtype: float64
